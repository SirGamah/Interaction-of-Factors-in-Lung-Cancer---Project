# %% [markdown]
# About Dataset
#
# 📌 Overview
#
# This dataset has been carefully synthesized to support research in lung cancer survival prediction, enabling the development of models that estimate:
#
# 1. Whether a patient is likely to survive at least one year post-diagnosis (Binary Classification).
# 2. The probability of survival based on clinical and lifestyle factors (Regression Analysis).
#
# The dataset is designed for machine learning and deep learning applications in medical AI, oncology research, and predictive healthcare.
#
# 📜 Dataset Generation Process
#
# The dataset was generated using a combination of real-world epidemiological insights, medical literature, and statistical modeling. The feature distributions and relationships have been carefully modeled to reflect real-world clinical scenarios, ensuring biomedical validity.
#
# 📖 Medical References & Sources
#
# The dataset structure is based on well-established lung cancer risk factors and survival indicators documented in leading medical research and clinical guidelines:
#
#   * World Health Organization (WHO) Reports on lung cancer epidemiology.
#   * National Cancer Institute (NCI) & American Cancer Society (ACS) guidelines on lung cancer risk factors and treatment outcomes.
#   * The IASLC Lung Cancer Staging Project (8th Edition): Standard reference for lung cancer staging.
#   * Harrison’s Principles of Internal Medicine (20th Edition): Provides an in-depth review of lung cancer diagnosis and treatment.
#   * Lung Cancer: Principles and Practice (2022, Oxford University Press): Clinical insights into lung cancer detection, treatment, and survival factors.
#
# 🔬 Features of the Dataset
# Each record in the dataset represents an individual’s clinical condition, lifestyle risk factors, and survival outcome. The dataset includes the following features:
#
# 1️⃣ Patient Demographics
#
# * Age → A key risk factor for lung cancer progression and survival.
# * Gender → Male and female lung cancer survival rates can differ.
# * Residence → Urban vs. Rural (impact of environmental factors).
#
# 2️⃣ Risk Factors & Lifestyle Indicators
#
# These factors have been linked to lung cancer risk in epidemiological studies:
#
# * Smoking Status → (Current Smoker, Former Smoker, Never Smoked).
# * Air Pollution Exposure → (Low, Moderate, High).
# * Biomass Fuel Use → (Yes/No) – Associated with household air pollution.
# * Factory Exposure → (Yes/No) – Industrial exposure increases lung cancer risk.
# * Family History → (Yes/No) – Genetic predisposition to lung cancer.
# * Diet Habit → (Vegetarian, Non-Vegetarian, Mixed) – Nutritional impact on cancer progression.
#
# 3️⃣ Symptoms (Primary Predictors)
#
# These are key clinical indicators associated with lung cancer detection and severity:
#
# * Hemoptysis (Coughing Blood)
# * Chest Pain
# * Fatigue & Weakness
# * Chronic Cough
# * Unexplained Weight Loss
#
# 4️⃣ Tumor Characteristics & Clinical Features
#
# * Tumor Size (mm) → The size of the detected tumor.
# * Histology Type → (Adenocarcinoma, Squamous Cell Carcinoma, Small Cell Carcinoma).
# * Cancer Stage → (Stage I to Stage IV).
#
# 5️⃣ Treatment & Healthcare Facility
#
# * Treatment Received → (Surgery, Chemotherapy, Radiation, Targeted Therapy).
# * Hospital Type → (Private, Government, Medical College).
#
# 6️⃣ Target Variables (Predicted Outcomes)
#
# * Survival (Binary) → 1 (Yes) if the patient survives at least 1 year, 0 (No) otherwise.
# * Survival Probability (%) (Can be derived) → Estimated probability of survival within one year.

# %% [markdown]
# ## Data Loading

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nishatvasker/lung-cancer-bangladesh")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'lung-cancer-bangladesh' dataset.
# Path to dataset files: /kaggle/input/lung-cancer-bangladesh

# %%
# !ls {path}
# Out:
# Large_Synthetic_Lung_Cancer_Dataset__Bangladesh_Perspective_.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(f"{path}/Large_Synthetic_Lung_Cancer_Dataset__Bangladesh_Perspective_.csv")
df.head()
# Out:
#   Patient_ID  Age  Gender  Smoking_Status Residence Air_Pollution_Exposure  \
# 0   BD-00001   84    Male   Former Smoker     Urban               Moderate
# 1   BD-00002   34  Female  Current Smoker     Urban                    Low
# 2   BD-00003   45    Male    Never Smoked     Urban                   High
# 3   BD-00004   47  Female   Former Smoker     Urban               Moderate
# 4   BD-00005   78    Male    Never Smoked     Rural                   High
#
#   Biomass_Fuel_Use Factory_Exposure Family_History      Diet_Habit  \
# 0               No              Yes             No  Non-Vegetarian
# 1              Yes               No             No           Mixed
# 2               No               No             No           Mixed
# 3               No              Yes             No  Non-Vegetarian
# 4              Yes               No             No  Non-Vegetarian
#
#       Symptoms  Tumor_Size_mm           Histology_Type      Stage  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Patient_ID              5000 non-null   object
#  1   Age                     5000 non-null   int64
#  2   Gender                  5000 non-null   object
#  3   Smoking_Status          5000 non-null   object
#  4   Residence               5000 non-null   object
#  5   Air_Pollution_Exposure  5000 non-null   object
#  6   Biomass_Fuel_Use        5000 non-null   object
#  7   Factory_Exposure        5000 non-null   object
#  8   Family_History          5000 non-null   object
#  9   Diet_Habit              5000 non-null   object
#  10  Symptoms                5000 non-null   object
#  11  Tumor_Size_mm           5000 non-null   int64
#  12  Histology_Type          5000 non-null   object
#  13  Stage                   5000 non-null   object
# ...

# %% [markdown]
# ## Data Exploration and Analysis

# %% [markdown]
# ### 1. Age Analysis

# %%
# Plot histogram of `Age`
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# This plot highlights the importance of age as a factor in lung cancer.
#
# * The impact of genetic vulnerabilities can become more apparent or significant with age due to accumulated environmental exposures and biological changes. Analyzing age alongside genetic data could help identify age-specific genetic risk factors.

# %%
# Box plot of `Age`
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Age'])
plt.title('Box Plot of Age')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# The box plot provides a summary of the age distribution, showing the median, quartiles, and potential outliers.
# * Genetic predispositions to lung cancer can manifest at different ages. Some genetic factors might increase risk earlier in life, while others might become more influential with age due to cumulative factors.
# * The box plot reinforces the idea that lung cancer affects individuals across a broad age spectrum.

# %%
# Plot `Age` vs `Survival`
plt.figure(figsize=(10, 6))
sns.boxplot(x='Survival_1_Year', y='Age', data=df)
plt.title('Age vs Survival')
plt.xlabel('Survival')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# This box plot compares the age distribution of patients who survived for at least one year (`'Yes'`) versus those who did not (`'No'`). From the plot, it appears that the median age and the overall distribution of ages are quite similar between the two survival groups. The boxes and whiskers for both `'Yes'` and `'No'` survival outcomes largely overlap.
# * This plot suggests that age by itself might not be a strong predictor of one-year survival in this dataset. This highlights the need to consider other factors, including genetic vulnerabilities, to better understand survival outcomes.
# * While the marginal effect of age on survival appears limited here, it's possible that genetic factors interact with age in complex ways that are not evident in this simple box plot.
# * To achieve precision in disease prevention and treatment, we need to move beyond analyzing single factors in isolation. Integrating genetic information with clinical data like age, tumor characteristics, and treatment received is essential for building more accurate predictive models for survival.

# %%
# Plot histogram of `Age` colored by `Survival_1_Year`
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', hue='Survival_1_Year', kde=True)
plt.title('Distribution of Age by Survival')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot histogram of `Age` colored by `Survival_1_Year`
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Age', hue='Survival_1_Year', kde=True)
plt.title('Distribution of Age by Survival')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.subplot(1, 2, 2)
sns.boxplot(x='Survival_1_Year', y='Age', data=df)
plt.title('Age vs Survival')
plt.xlabel('Survival')
plt.ylabel('Age')
plt.tight_layout()
plt.show()

# %% [markdown]
# This stacked histogram provides a more detailed look at the age distribution for both survival groups ('Yes' and 'No'). Similar to the box plot, this visualization reinforces the observation that the age distributions for those who survived and those who did not are quite similar. The overlap in the distributions across different age bins suggests that there isn't a clear age range where survival is significantly higher or lower based solely on age.
# * While age itself might not be a primary determinant of one-year survival, it could still act as a modifying factor for genetic vulnerabilities.
# * This visualization reinforces the idea that purely age-based prevention or treatment strategies might not be sufficient for lung cancer.

# %% [markdown]
# ### 2. Gender Analysis

# %%
# Plot distribution of `Gender`
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', data=df)
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This box plot displays the number of `male` and `female` individuals in the dataset. It appears there are significantly more `male` patients than `female` patients in this dataset.
# * It is known that there can be biological and genetic differences between males and females that influence disease susceptibility and progression, including certain types of cancer. Analyzing the distribution of gender is a first step in understanding if gender might play a role in lung cancer risk or survival in this dataset.
# * Some genetic mutations or variations might be more common or have a different impact in one gender compared to the other. Identifying these gender-specific genetic vulnerabilities is crucial for precision prevention.

# %%
# Gender by `Survival_1_Year` analysis
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', hue='Survival_1_Year', data=df)
plt.title('Gender by Survival')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of `male` and `female` patients, broken down by whether they survived for at least one year (`'Yes'`) or not (`'No'`). From the plot, we can observe the survival counts for each gender. While there are more male patients overall, we can compare the proportion of survivors within each gender group.
# * This plot allows us to see if there are apparent differences in one-year survival rates between males and females in this dataset. The disparities indicate that gender-specific biological or genetic factors play a role in survival outcomes.
# * If gender is found to be a significant factor in survival, the next step in precision prevention would be to investigate if specific genetic vulnerabilities are more prevalent or have a stronger impact on survival in one gender compared to the other.

# %% [markdown]
# ### 3. Smoking Status Analysis

# %%
# Distribution of `Smoking Status`
plt.figure(figsize=(10, 6))
sns.countplot(x='Smoking_Status', data=df)
plt.title('Distribution of Smoking Status')
plt.xlabel('Smoking Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot shows the number of individuals in each smoking status category: `'Former Smoker'`, `'Current Smoker'`, and `'Never Smoked'`. From the plot, it appears that `'Current Smoker'` is the largest category, followed by `'Former Smoker'` and then `'Never Smoked'`.
# * Smoking is a well-established and significant risk factor for lung cancer. The distribution here highlights the prevalence of smoking in this dataset, which is expected in a lung cancer study.
# * Genetic vulnerabilities can interact with environmental factors like smoking exposure to increase lung cancer risk.
# * Combining smoking status with genetic risk profiles can help stratify individuals into different risk categories, allowing for more precise screening and early detection efforts.

# %%
# Smoking Status by Suvival analysis
plt.figure(figsize=(10, 6))
sns.countplot(x='Smoking_Status', hue='Survival_1_Year', data=df)
plt.title('Smoking Status by Survival')
plt.xlabel('Smoking Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients in each smoking status category, broken down by whether they survived for at least one year (`'Yes'`) or not (`'No'`).
# * We can see the proportion of survivors within the 'Former Smoker', 'Current Smoker', and 'Never Smoked' categories. Differences in these proportions could suggest that smoking status, or factors associated with it, influence survival.
# * If specific genetic vulnerabilities are found to be more prevalent or have a greater impact on survival in smokers, treatment strategies could be tailored accordingly. This could involve using specific therapies that are more effective in individuals with certain genetic profiles and smoking histories.

# %% [markdown]
# ### 4. Residence Analysis

# %%
# Plot distribution `Residence`
plt.figure(figsize=(10, 6))
sns.countplot(x='Residence', data=df)
plt.title('Distribution of Residence')
plt.xlabel('Residence')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals residing in `Urban` versus `Rural` areas in the dataset. It appears there are more patients from urban areas than rural areas in this dataset.
# * Residence can be a proxy for various environmental exposures, such as air pollution or lifestyle differences. Genetic vulnerabilities can interact with these environmental factors to influence lung cancer risk.
# * The prevalence of certain genetic variations might differ between urban and rural populations due to historical migration patterns or other demographic factors.
# * If specific genetic vulnerabilities are found to be more impactful in certain residential settings prevention strategies could be tailored.

# %%
# Distribution Residence by Survival
plt.figure(figsize=(10, 6))
sns.countplot(x='Residence', hue='Survival_1_Year', data=df)
plt.title('Residence by Survival')
plt.xlabel('Residence')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients residing in `Urban` versus `Rural` areas, broken down by whether they survived for at least one year (`'Yes'`) or not (`'No'`).
# * The significant disparities suggest that factors associated with residence, such as environmental exposures or access to healthcare influence survival.
# * Genetic vulnerabilities can interact with environmental factors linked to residence to impact survival.
# * If specific genetic vulnerabilities are found to have a greater impact on survival in certain residential settings, interventions can be targeted.

# %% [markdown]
# ### 5. Air Pollution Exposure Analysis

# %%
# Air_Pollution_Exposure distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Air_Pollution_Exposure', data=df)
plt.title('Distribution of Air Pollution Exposure')
plt.xlabel('Air Pollution Exposure')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals categorized by their level of air pollution exposure: `'Low'`, `'Moderate'`, and `'High'`. From the plot, it appears that `'High'` exposure is the largest category, followed by `'Moderate'` and then `'Low'`.
# * Air pollution is a recognized environmental risk factor for lung cancer. The distribution shown here highlights the varying levels of exposure within the dataset's population.
# * Genetic vulnerabilities can influence an individual's susceptibility to the harmful effects of air pollutants. Some genetic variations might impair the body's ability to detoxify pollutants or repair pollution-induced DNA damage, increasing the risk of lung cancer.
# * Combining information on air pollution exposure with an individual's genetic profile can lead to a more precise assessment of their lung cancer risk.

# %%
# Air Pollution Exposure by Residence
plt.figure(figsize=(10, 6))
sns.countplot(x='Air_Pollution_Exposure', hue='Residence', data=df)
plt.title('Air Pollution Exposure by Residence')
plt.xlabel('Air Pollution Exposure')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients categorized by their level of air pollution exposure (`'Low'`, `'Moderate'`, and `'High'`), broken down by their residence in `'Urban'` versus `'Rural'` areas.
#
# *   This plot reveals a relationship between residence and air pollution exposure, with a higher number of urban residents experiencing moderate and high air pollution exposure compared to rural residents. This is an expected finding, as urban areas often have higher levels of industrial and traffic-related air pollution.
# *   This relationship is important for precision prevention because it highlights how a specific environmental exposure (air pollution) is linked to a geographic location. Genetic vulnerabilities can interact with this exposure. Individuals with genetic predispositions that make them more susceptible to the harmful effects of air pollution might face a higher risk if they reside in urban areas with higher exposure levels.
# *   Identifying these interactions between genetic vulnerabilities and environmental factors like air pollution exposure in specific residential settings is crucial for developing targeted prevention strategies. For example, individuals with a high genetic risk and who live in areas with high air pollution could be prioritized for stricter air quality regulations or provided with personalized recommendations to minimize their exposure.

# %%
# Air_Pollution_Exposure by Survival
plt.figure(figsize=(10, 6))
sns.countplot(x='Air_Pollution_Exposure', hue='Survival_1_Year', data=df)
plt.title('Air Pollution Exposure by Survival')
plt.xlabel('Air Pollution Exposure')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients categorized by their level of air pollution exposure (`'Low'`, `'Moderate'`, and `'High'`), broken down by whether they survived for at least one year (`'Yes'`) or not (`'No'`).
# * This plot allows us to see if there are differences in one-year survival rates among individuals with different levels of air pollution exposure. Observing disparities in survival proportions across the exposure categories could suggest that air pollution influences survival outcomes.
# * Genetic vulnerabilities can influence how an individual's body responds to air pollution exposure, which in turn can affect tumor progression and survival.

# %% [markdown]
# #### 6. Biomass Fuel Use

# %%
# Distribution of `Biomass_Fuel_Use`
plt.figure(figsize=(10, 6))
sns.countplot(x='Biomass_Fuel_Use', data=df)
plt.title('Distribution of Biomass Fuel Use')
plt.xlabel('Biomass Fuel Use')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals who reported using biomass fuel (`'Yes'`) versus those who did not (`'No'`). Biomass fuel use is often associated with indoor air pollution, particularly in rural areas, and is a known risk factor for respiratory diseases, including lung cancer. From the plot, it appears that a significant portion of the dataset's population uses biomass fuel.
# * Biomass fuel use represents an environmental exposure that contributes to the risk of lung cancer. The distribution here highlights the prevalence of this risk factor in the dataset.
# * Genetic vulnerabilities can influence an individual's susceptibility to the harmful components of indoor air pollution from biomass fuel combustion. Some genetic variations might affect the body's ability to process these pollutants or repair resulting cellular damage, increasing lung cancer risk. Identifying these genetic links is crucial for precision prevention.

# %%
# Biomass_Fuel_Use by Resisdence type
plt.figure(figsize=(10, 6))
sns.countplot(x='Biomass_Fuel_Use', hue='Residence', data=df)
plt.title('Biomass Fuel Use by Residence')
plt.xlabel('Biomass Fuel Use')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients who use biomass fuel (`'Yes'`) versus those who do not (`'No'`), broken down by their residence in `'Urban'` versus `'Rural'` areas.
# * This plot shows a clear correlation between biomass fuel use and residence, with a higher proportion of individuals in rural areas using biomass fuel compared to urban areas. This aligns with the understanding that biomass fuel is often used for cooking and heating in rural settings.
# * This correlation is significant for precision prevention because it highlights how a specific environmental exposure (indoor air pollution from biomass fuel) is concentrated in a particular geographic setting. Genetic vulnerabilities can interact with this exposure. Individuals with genetic predispositions that make them more susceptible to the harmful effects of indoor air pollution might face a higher risk if they reside in rural areas and use biomass fuel.

# %%
# Biomass_Fuel_Use by Survival
plt.figure(figsize=(10, 6))
sns.countplot(x='Biomass_Fuel_Use', hue='Survival_1_Year', data=df)
plt.title('Biomass Fuel Use by Survival')
plt.xlabel('Biomass Fuel Use')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients who use biomass fuel (`'Yes'`) versus those who do not (`'No'`), broken down by whether they survived for at least one year (`'Yes'`) or not (`'No'`).
# * This plot allows us to see if there are differences in survival rates between individuals who use biomass fuel and those who do not. Observing disparities in survival proportions could suggest that biomass fuel use, or the associated indoor air pollution, influences survival outcomes.
# * Genetic vulnerabilities can influence how an individual's body responds to the pollutants from biomass fuel combustion, which can affect tumor progression and survival.
# * If specific genetic vulnerabilities are found to have a greater impact on survival in individuals who use biomass fuel, treatment plans and supportive care could be tailored.

# %% [markdown]
# ### 7. Factory Exposure Analysis

# %%
# Distribution of `Factory_Exposure`
plt.figure(figsize=(10, 6))
sns.countplot(x='Factory_Exposure', data=df)
plt.title('Distribution of Factory Exposure')
plt.xlabel('Factory Exposure')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals who reported being exposed to factories ('Yes') versus those who were not ('No'). Industrial exposure is another potential environmental risk factor for lung cancer, as factories can release various pollutants into the air. From the plot, it appears that a significant majority of the dataset's population reported no factory exposure.
# * Factory exposure represents an environmental exposure that could contribute to lung cancer risk, depending on the types of pollutants involved. The distribution here shows the prevalence of this potential risk factor in the dataset.
# * Genetic vulnerabilities can influence an individual's susceptibility to the harmful components of industrial pollutants. Some genetic variations might affect the body's ability to detoxify these chemicals or repair the damage they cause, increasing lung cancer risk.

# %%
# Factory exposure by Survival
plt.figure(figsize=(10, 6))
sns.countplot(x='Factory_Exposure', hue='Survival_1_Year', data=df)
plt.title('Factory Exposure by Survival')
plt.xlabel('Factory Exposure')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients who reported being exposed to factories (`'Yes'`) versus those who were not (`'No'`), broken down by whether they survived (`'Yes'`) or not (`'No'`).
# * This plot allows us to see if there are differences in survival rates between individuals with and without factory exposure. Observing disparities in survival proportions could suggest that factory exposure, or the associated industrial pollutants, influences survival outcomes.
# * Genetic vulnerabilities can influence how an individual's body responds to industrial pollutants, which can affect tumor progression and survival.

# %% [markdown]
# ### 8. Family History Analysis

# %%
# Distribution of Family History
plt.figure(figsize=(10, 6))
sns.countplot(x='Family_History', data=df)
plt.title('Distribution of Family History')
plt.xlabel('Family History')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals who reported a family history of lung cancer (`'Yes'`) versus those who did not (`'No'`). A family history of cancer is a strong indicator of potential genetic predisposition. From the plot, it appears that a significant majority of the dataset's population reported no family history of lung cancer.
# * Family history is often the first indicator of inherited genetic vulnerabilities. A positive family history suggests that genetic factors may play a role in the increased risk of lung cancer within that family.
# * Individuals with a family history of lung cancer are considered to be at higher risk, and this risk is often linked to inherited genetic mutations. Identifying these individuals is a primary step in precision prevention.
# * For individuals with a family history, targeted genetic screening can be offered to identify specific inherited mutations known to increase lung cancer risk (e.g., mutations in genes like EGFR, ALK, or others depending on the type of lung cancer).

# %%
# Family_History by Survivial status
plt.figure(figsize=(10, 6))
sns.countplot(x='Family_History', hue='Survival_1_Year', data=df)
plt.title('Family History by Survival')
plt.xlabel('Family History')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients who reported a family history of lung cancer (`'Yes'`) versus those who did not (`'No'`), broken down by whether they survived for at least one year (`'Yes'`) or not (`'No'`).
# * This plot allows us to see if there are differences in survival rates between individuals with and without a family history of lung cancer. Observing disparities in survival proportions could suggest that genetic factors associated with family history influence survival outcomes.
# * If individuals with a family history show different survival rates, it could indicate that the inherited genetic vulnerabilities not only increase the risk of developing lung cancer but also influence how the disease progresses and responds to treatment.

# %% [markdown]
# ### 9. Diet Habit Analysis

# %%
# Distribution of Diet Habit
plt.figure(figsize=(10, 6))
sns.countplot(x='Diet_Habit', data=df)
plt.title('Distribution of Diet Habit')
plt.xlabel('Diet Habit')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals in each diet habit category: `'Non-Vegetarian'`, `'Mixed'`, and `'Vegetarian'`. From the plot, `'Non-Vegetarian'` appears to be the largest category, followed by `'Mixed'`, and then `'Vegetarian'`.
#
# *   Diet is a lifestyle factor that can influence overall health and susceptibility to various diseases, including cancer. The distribution of diet habits in this dataset provides context on the dietary patterns of the population studied.
# *   Genetic vulnerabilities can interact with dietary factors. For example, genetic variations might affect how an individual metabolizes certain nutrients or processes dietary carcinogens, which could influence their risk of developing lung cancer.
# *   Understanding the distribution of diet habits is a step towards exploring these gene-diet interactions. If certain genetic profiles are found to confer a higher risk of lung cancer in individuals with specific dietary patterns, this information could be used for personalized dietary recommendations as a form of precision prevention. For instance, individuals with a particular genetic vulnerability might be advised to adopt a diet richer in certain protective nutrients or to limit the intake of specific foods that could increase their risk in the presence of that vulnerability.

# %%
# Diet Habit by Survival
plt.figure(figsize=(10, 6))
sns.countplot(x='Diet_Habit', hue='Survival_1_Year', data=df)
plt.title('Diet Habit by Survival')
plt.xlabel('Diet Habit')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients in each diet habit category, broken down by whether they survived for at least one year (`'Yes'`) or not (`'No'`).
#
# *   This plot allows us to see if there are apparent differences in survival rates among individuals with different diet habits. Observing disparities in survival proportions across the diet categories could suggest that diet, or factors associated with it, influences survival outcomes.
# *   Genetic vulnerabilities can interact with dietary factors to influence how the body responds to cancer and its treatment, thereby affecting survival. For example, certain genetic profiles might influence the effectiveness of specific treatments in individuals with particular dietary patterns.
# *   If specific genetic vulnerabilities are found to have a greater impact on survival in individuals with certain dietary habits, this information can be used to develop personalized treatment plans or supportive care strategies. This aligns with precision prevention, where interventions are tailored based on an individual's genetic makeup and lifestyle factors like diet to improve outcomes.

# %% [markdown]
# ### 10. Symptoms Analysis

# %%
# Distribution of Symptoms
plt.figure(figsize=(10, 6))
sns.countplot(x='Symptoms', data=df)
plt.title('Distribution of Symptoms')
plt.xlabel('Symptoms')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals reporting each of the listed symptoms: `'Hemoptysis'`, `'Chest Pain'`, `'Fatigue'`, `'Cough'`, `'Weight Loss'`, and `'Shortness of Breath'`. From the plot, it appears that the counts for each symptom are relatively balanced in this dataset.
#
# *   Symptoms are often key indicators of disease presence and progression. The distribution here shows the prevalence of different symptoms within the lung cancer patient population in this dataset.
# *   Genetic vulnerabilities can influence the type and severity of symptoms an individual experiences. For example, certain genetic profiles might be associated with particular tumor characteristics or pathways that manifest as specific symptoms.
# *   Understanding the link between genetic vulnerabilities and symptom presentation can be valuable for precision prevention and early detection. If certain genetic profiles are associated with specific early symptoms, individuals with those profiles could be educated to recognize these symptoms and seek medical attention promptly. This could lead to earlier diagnosis and potentially better outcomes.

# %%
# Symptoms by Survival
plt.figure(figsize=(10, 6))
sns.countplot(x='Symptoms', hue='Survival_1_Year', data=df)
plt.title('Symptoms by Survival')
plt.xlabel('Symptoms')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients reporting each of the listed symptoms, broken down by whether they survived (`'Yes'`) or not (`'No'`).
#
# *   This plot allows us to see if there are differences in survival rates among individuals who presented with different symptoms. Observing disparities in survival proportions across symptom categories could suggest that the initial symptoms experienced influence survival outcomes.
# *   Genetic vulnerabilities can influence how the disease progresses and responds to treatment, which in turn can affect survival. These genetic factors might also be linked to the type or severity of symptoms.
# *   If specific genetic vulnerabilities are found to be associated with certain symptoms and also impact survival, this information could be used for personalized prognostication and treatment planning. For example, individuals with a particular genetic profile and a specific set of symptoms might be at higher risk of poorer survival and could benefit from more aggressive or targeted therapies. This aligns with precision prevention by using genetic and symptomatic information to tailor interventions and improve outcomes.

# %% [markdown]
# ### 11. Tumor Size Analysis

# %%
# Histogram plot of Tumor Size
plt.figure(figsize=(10, 6))
sns.histplot(df['Tumor_Size_mm'], bins=20, kde=True)
plt.title('Distribution of Tumor Size')
plt.xlabel('Tumor Size')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# This histogram plot displays the distribution of tumor sizes in millimeters (`Tumor_Size_mm`) among the patients in the dataset. The histogram shows the frequency of tumors within different size ranges, and the kernel density estimate (KDE) provides a smoothed representation of the distribution.
#
# *   Tumor size is a critical prognostic factor in lung cancer. Generally, larger tumors are associated with more advanced disease stages and potentially poorer outcomes. The distribution here provides insight into the range and prevalence of tumor sizes in this patient population.
# *   Genetic vulnerabilities can influence tumor growth rates and the size at which a tumor is detected. For example, certain genetic mutations might lead to more aggressive tumor growth.
# *   Understanding the relationship between genetic vulnerabilities and tumor size is important for precision prevention and treatment. If specific genetic profiles are linked to faster-growing tumors or larger tumor sizes at diagnosis, individuals with these profiles could benefit from more frequent or advanced screening methods to detect tumors at an earlier, potentially more treatable stage. Furthermore, treatment strategies could be tailored based on both the tumor size and the patient's genetic profile to optimize outcomes.

# %%
# Box plot for Tumor Size
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Tumor_Size_mm'])
plt.title('Box Plot of Tumor Size')
plt.xlabel('Tumor Size')
plt.show()

# %% [markdown]
# The boz plot shows no outliers present

# %%
# Histogram of the distribution of Tumor Size by Survival
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Tumor_Size_mm', hue='Survival_1_Year', kde=True)
plt.title('Distribution of Tumor Size by Survival')
plt.xlabel('Tumor Size')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# This stacked histogram displays the distribution of tumor sizes for patients who survived  (`'Yes'`) versus those who did not (`'No'`). The histogram shows the frequency of tumors within different size ranges for each survival group, and the kernel density estimates (KDE) provide smoothed representations of these distributions.
#
# *   This plot allows us to see if there are differences in the distribution of tumor sizes between the survival groups. Observing shifts or differences in the peaks and shapes of the histograms could suggest that tumor size at diagnosis influences survival outcomes. Generally, smaller tumor sizes are associated with better prognoses.
# *   Genetic vulnerabilities can influence tumor growth rates and potentially the size at which a tumor is detected, which in turn can affect survival.
# *   Understanding the interplay between genetic vulnerabilities and tumor size in relation to survival is key for precision prevention and treatment. If certain genetic profiles are linked to larger tumor sizes at diagnosis and poorer survival, individuals with these profiles could be targeted for more intensive screening to detect tumors earlier. Additionally, treatment strategies could be personalized based on both the tumor size and the patient's genetic makeup to improve the chances of survival. This aligns with precision prevention by using a combination of clinical and genetic information to tailor interventions for better outcomes.

# %% [markdown]
# ### 12. Histology Type Analysis

# %%
# Histology Type distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Histology_Type', data=df)
plt.title('Distribution of Histology Type')
plt.xlabel('Histology Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals with each histology type: `'Adenocarcinoma'`, `'Small Cell Carcinoma'`, `'Squamous Cell Carcinoma'`, and `'Large Cell Carcinoma'`. From the plot, `'Adenocarcinoma'` appears to be the most common histology type in this dataset, followed by `'Squamous Cell Carcinoma'`, `'Small Cell Carcinoma'`, and then `'Large Cell Carcinoma'`.
#
# *   Histology type is a crucial factor in lung cancer diagnosis, prognosis, and treatment. Different histology types have distinct molecular characteristics, growth patterns, and responses to therapy. The distribution here shows the prevalence of these different types within the patient population.
# *   Genetic vulnerabilities are often specific to certain histology types. For example, mutations in the *EGFR* gene are more common in adenocarcinomas, while mutations in the *KRAS* gene are also frequently found in adenocarcinomas but have different prognostic implications. Small cell lung carcinoma is strongly associated with smoking and has a different genetic landscape compared to non-small cell lung cancers.
# *   Understanding the distribution of histology types is essential for precision prevention and treatment because genetic testing and targeted therapies are often tailored to specific histology types. Identifying the genetic vulnerabilities associated with each histology type allows for more precise risk assessment, screening strategies, and treatment selection. For instance, individuals with a genetic predisposition for a specific histology type could be monitored more closely for that particular type of cancer, and if diagnosed, receive treatments specifically designed for that histology and their genetic profile.

# %%
# Histology type and Survival
plt.figure(figsize=(10, 6))
sns.countplot(x='Histology_Type', hue='Survival_1_Year', data=df)
plt.title('Histology Type by Survival')
plt.xlabel('Histology Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients with each histology type, broken down by whether they survived for at least one year (`'Yes'`) or not (`'No'`).
#
# *   This plot allows us to see if there are differences in survival rates among individuals with different histology types. Observing disparities in survival proportions across the histology categories could suggest that histology type influences survival outcomes. Different histology types have varying aggressiveness and responsiveness to treatments, which would impact survival.
# *   Genetic vulnerabilities are strongly linked to specific histology types and can influence both the development and the prognosis of lung cancer. For example, the presence of certain genetic mutations (like EGFR or ALK rearrangements) in adenocarcinomas can predict a better response to targeted therapies and thus potentially improve survival. Conversely, some genetic profiles might be associated with more aggressive disease and poorer outcomes within a specific histology type.
# *   Understanding the interplay between genetic vulnerabilities, histology type and survival is paramount for precision prevention and treatment. Genetic testing to identify specific mutations relevant to the diagnosed histology type allows for personalized treatment selection with targeted therapies or immunotherapies that are more likely to be effective. This precision approach, guided by both histology and genetic information, aims to improve survival rates and reduce treatment side effects, aligning perfectly with the goals of precision prevention and personalized medicine.

# %% [markdown]
# ### 13. Stage Analysis

# %%
# Stage distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Stage', data=df)
plt.title('Distribution of Stage')
plt.xlabel('Stage')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals diagnosed at each cancer stage: `'Stage I'`, `'Stage II'`, `'Stage III'`, and `'Stage IV'`. From the plot, `'Stage II'` and `'Stage III'` appear to have the highest counts, followed by `'Stage I'` and then `'Stage IV'`.
#
# *   Cancer stage at diagnosis is one of the most significant prognostic factors for lung cancer. Generally, earlier stages (I and II) are associated with better prognoses and higher survival rates compared to later stages (III and IV). The distribution here shows the stages at which patients in this dataset were diagnosed.
# *   Genetic vulnerabilities can influence the rate of tumor progression and metastasis, which in turn affects the stage at which the cancer is diagnosed. Some genetic profiles might be associated with more aggressive tumors that are detected at later stages.
# *   Understanding the link between genetic vulnerabilities and cancer stage is critical for precision prevention and early detection. If specific genetic profiles are found to be associated with a higher likelihood of being diagnosed at a later stage, individuals with these profiles could be targeted for more intensive or frequent screening to detect the cancer at an earlier, more treatable stage. This early detection, guided by genetic risk, is a key component of precision prevention and can significantly improve survival outcomes.

# %%
# Stage by Survival
plt.figure(figsize=(10, 6))
sns.countplot(x='Stage', hue='Survival_1_Year', data=df)
plt.title('Stage by Survival')
plt.xlabel('Stage')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients diagnosed at each cancer stage, broken down by whether they survived (`'Yes'`) or not (`'No'`).
#
# *   This plot allows us to see if there are differences in survival rates among individuals diagnosed at different stages. Observing disparities in survival proportions across the stage categories could suggest that the stage at diagnosis significantly influences survival outcomes. As expected, patients diagnosed at earlier stages (I and II) tend to have a higher proportion of survivors compared to those diagnosed at later stages (III and IV).
# *   Genetic vulnerabilities can influence both the stage at which cancer is diagnosed and how the disease progresses, thereby impacting survival. Some genetic profiles might be associated with more aggressive tumors that are likely to be diagnosed at later stages and have poorer prognoses.
# *   Understanding the interplay between genetic vulnerabilities, cancer stage, and survival is crucial for precision prevention and treatment. If specific genetic profiles are found to be associated with a higher likelihood of late-stage diagnosis and poorer survival, individuals with these profiles could be targeted for more intensive screening and early detection efforts. Additionally, treatment strategies can be personalized based on both the cancer stage and the patient's genetic makeup to optimize outcomes. This precision approach, guided by a combination of staging and genetic information, aims to improve survival rates and personalize interventions.

# %% [markdown]
# ### 14. Treatment Analysis

# %%
# Treatment distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Treatment', data=df)
plt.title('Distribution of Treatment')
plt.xlabel('Treatment')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals who received each type of treatment: `'Chemotherapy'`, `'Targeted Therapy'`, `'Surgery'`, `'Radiation'`, and `'Palliative Care'`. From the plot, `'Chemotherapy'` appears to be the most common treatment received by patients in this dataset, followed by `'Radiation'`, `'Surgery'`, `'Targeted Therapy'`, and then `'Palliative Care'`.
#
# *   Treatment received is a critical factor influencing survival outcomes in lung cancer. Different treatment modalities are more effective for specific histology types, stages, and genetic profiles. The distribution here shows the common treatment approaches used in this patient population.
# *   Genetic vulnerabilities can significantly influence how a patient responds to different treatments. For example, tumors with certain genetic mutations are highly responsive to targeted therapies, while others might be more sensitive to chemotherapy or radiation. Understanding these gene-treatment interactions is a cornerstone of precision oncology.
# *   Analyzing the distribution of treatments received is a step towards exploring how genetic vulnerabilities might influence treatment decisions and outcomes. If specific genetic profiles are more prevalent in patients receiving certain treatments, and these treatments are associated with different survival rates, it could indicate that treatment selection is already being influenced by factors potentially linked to genetics.
# *   For precision prevention and treatment, identifying genetic vulnerabilities that predict response to specific therapies is crucial. This allows for tailoring treatment plans based on an individual's genetic makeup, ensuring they receive the most effective treatment for their specific cancer, thereby improving survival rates and minimizing adverse effects. This plot serves as a baseline to understand the current treatment landscape in this dataset before delving into how genetic factors might refine these approaches for better precision.

# %%
# Treatment by Survival
plt.figure(figsize=(10, 6))
sns.countplot(x='Treatment', hue='Survival_1_Year', data=df)
plt.title('Treatment by Survival')
plt.xlabel('Treatment')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients who received each type of treatment, broken down by whether they survived (`'Yes'`) or not (`'No'`).
#
# *   This plot allows us to see if there are differences in survival rates among individuals who received different treatments. Observing disparities in survival proportions across the treatment categories could suggest that the type of treatment significantly influences  survival outcomes.
# *   Genetic vulnerabilities can influence how a patient's cancer responds to specific treatments, thereby impacting survival. For example, tumors with certain genetic mutations might be resistant to conventional chemotherapy but highly sensitive to targeted therapies.
# *   Understanding the interplay between genetic vulnerabilities, treatment received, and survival is crucial for precision prevention and treatment. If specific genetic profiles are found to be associated with better or worse responses to certain treatments, this information can be used to personalize treatment selection. Tailoring treatment plans based on an individual's genetic makeup and the likely effectiveness of different therapies is a core principle of precision oncology. This approach aims to maximize the chances of successful treatment and improve survival rates, aligning with the goals of precision prevention and personalized medicine.

# %% [markdown]
# ### 15. Hospital Type Analysis

# %%
# Hospital type distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Hospital_Type', data=df)
plt.title('Distribution of Hospital Type')
plt.xlabel('Hospital Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals who received treatment at each type of hospital: `'Private'`, `'Government'`, and `'Medical College'`. From the plot, `'Government'` hospitals appear to have treated the highest number of patients in this dataset, followed by `'Private'` hospitals and then `'Medical College'` hospitals.
#
# *   The type of hospital where a patient receives treatment can potentially influence outcomes due to differences in resources, specialization, access to advanced technologies, and treatment protocols. This distribution shows where patients in this dataset received care.
# *   Understanding the distribution of hospital types is relevant to precision prevention and treatment because it highlights potential disparities in access to care that might impact the effectiveness of personalized approaches. This plot provides context for considering how the healthcare infrastructure might influence survival.

# %%
# Hospital type by Residence
plt.figure(figsize=(10, 6))
sns.countplot(x='Hospital_Type', hue='Residence', data=df)
plt.title('Hospital Type by Residence')
plt.xlabel('Hospital Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients who received treatment at each type of hospital, broken down by their residence in `'Urban'` versus `'Rural'` areas.
#
# *   This plot reveals a relationship between residence and the type of hospital where patients receive care. We can observe the distribution of urban and rural patients across private, government, and medical college hospitals. This can highlight potential disparities in access to different types of healthcare facilities based on location.
# *   Understanding this relationship between residence, hospital type, and access to care is important for the practical implementation of precision prevention and treatment. This plot helps to visualize potential geographic barriers to accessing personalized healthcare, highlighting an area where interventions might be needed to ensure that the benefits of precision medicine are available to all patients, regardless of where they live.

# %%
# Hospital type by Survival
plt.figure(figsize=(10, 6))
sns.countplot(x='Hospital_Type', hue='Survival_1_Year', data=df)
plt.title('Hospital Type by Survival')
plt.xlabel('Hospital Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This stacked bar plot displays the number of patients who received treatment at each type of hospital, broken down by whether they survived (`'Yes'`) or not (`'No'`).
#
# *   This plot allows us to see if there are differences in survival rates among individuals treated at different types of hospitals. Observing disparities in survival proportions across the hospital types could suggest that the healthcare setting influences outcomes. This could be due to various factors, including the availability of resources, expertise, technology, and treatment protocols.
# *   Understanding the interplay between hospital type, and survival is important for ensuring equitable access to precision medicine. This plot helps to visualize potential differences in survival outcomes based on where patients receive care, highlighting the need to consider how healthcare infrastructure can impact the effectiveness of precision prevention and treatment strategies. Ensuring that all patients, regardless of where they receive care, have access to personalized treatments based on their genetic profile is essential for improving overall survival rates and achieving health equity.

# %% [markdown]
# ### 15. Survival Analysis

# %%
# Survival Analysis
plt.figure(figsize=(10, 6))
sns.countplot(x='Survival_1_Year', data=df)
plt.title('Distribution of Survival')
plt.xlabel('Survival')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This count plot displays the number of individuals who survived for at least one year (`'Yes'`) versus those who did not (`'No'`). From the plot, it appears that a higher number of patients in this dataset survived for at least one year compared to those who did not.
#
# *   Survival is the primary outcome variable in this analysis, reflecting the effectiveness of prevention, early detection, and treatment strategies. The distribution here provides a baseline understanding of the one-year survival rate in this patient population.
# *   Genetic vulnerabilities can play a significant role in determining survival outcomes. Some genetic profiles might be associated with more aggressive disease, poorer response to treatment, or a higher likelihood of recurrence, all of which can negatively impact survival. Conversely, other genetic profiles might be linked to slower disease progression, better treatment response, or a lower risk of complications, potentially leading to improved survival.
# *   Understanding the overall survival distribution is essential for the goal of precision prevention and treatment. The aim of precision medicine is to identify how individual genetic vulnerabilities, in combination with environmental and clinical factors, influence survival and to use this information to tailor interventions that improve these outcomes. Future analyses could delve deeper into how specific genetic profiles correlate with survival in this dataset, potentially revealing genetic markers that could be used for prognostic purposes or to guide personalized treatment decisions.

# %% [markdown]
# ## Split data

# %% [markdown]
# ### 1. Split data into `Features` and `Target`

# %%
# Split data into X and y
feature_cols = ['Age', 'Gender', 'Smoking_Status', 'Residence',
                'Air_Pollution_Exposure', 'Biomass_Fuel_Use', 'Factory_Exposure',
                'Family_History', 'Diet_Habit', 'Symptoms', 'Tumor_Size_mm',
                'Histology_Type', 'Stage', 'Treatment', 'Hospital_Type',]
X = df[feature_cols]
y = df['Survival_1_Year']

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### 1. Data Encoding

# %%
# One-hot encode all categorical features
X = pd.get_dummies(X, columns=['Gender', 'Smoking_Status', 'Residence',
                               'Air_Pollution_Exposure', 'Biomass_Fuel_Use',
                               'Factory_Exposure', 'Family_History', 'Diet_Habit',
                               'Symptoms', 'Histology_Type', 'Stage', 'Treatment',
                               'Hospital_Type'])

# %%
# Preview feature data
X.head()
# Out:
#    Age  Tumor_Size_mm  Gender_Female  Gender_Male  \
# 0   84             21          False         True
# 1   34             41           True        False
# 2   45             43          False         True
# 3   47             21           True        False
# 4   78             13          False         True
#
#    Smoking_Status_Current Smoker  Smoking_Status_Former Smoker  \
# 0                          False                          True
# 1                           True                         False
# 2                          False                         False
# 3                          False                          True
# 4                          False                         False
#
#    Smoking_Status_Never Smoked  Residence_Rural  Residence_Urban  \
# 0                        False            False             True
# 1                        False            False             True
# 2                         True            False             True
# ...

# %%
# Label encode target variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
# Preview target data
y[:5]
# Out:
# array([1, 1, 0, 1, 0])

# %% [markdown]
# ## Train-Test Split

# %%
# Split data into trainig and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Data sizes
print(f'X_train: {X_train.shape}')
print(f'X_test: {X_test.shape}')
print(f'y_train: {y_train.shape}')
print(f'y_test: {y_test.shape}')
# Out:
# X_train: (3500, 43)
# X_test: (1500, 43)
# y_train: (3500,)
# y_test: (1500,)

# %% [markdown]
# ## `Survival Probability` Estimation

# %% [markdown]
# ### 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
lr_survival_probs = model.predict_proba(X_test)[:, 1]

# %%
# Preview Survival Probability of Logistic Regression
lr_survival_probs[:5]
# Out:
# array([0.65915605, 0.73267086, 0.70329968, 0.71759007, 0.73453933])

# %%
# Plot the distribution
plt.figure(figsize=(10, 6))
sns.histplot(lr_survival_probs, bins=20, kde=True)
plt.title('Distribution of Survival Probability of Logistic Regression')
plt.xlabel('Survival Probability')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# This histogram displays the distribution of predicted survival probabilities from the Logistic Regression model.
#
# *   The histogram shows the frequency of different predicted survival probability values. A distribution centered around a certain probability suggests the model is predicting a range of survival likelihoods across the test set.
# *   Ideally, for a well-calibrated model, we would expect to see the predicted probabilities reflect the true likelihood of survival. The shape of the distribution can give us insights into how the model is performing. For instance, a bimodal distribution with peaks near 0 and 1 might indicate the model is confident in its predictions for many individuals, while a distribution heavily skewed towards the middle might suggest the model is less certain or that the classes are not easily separable based on the features.
# *   Analyzing the distribution of these probabilities is a step towards understanding the model's performance and how it can be used to inform personalized interventions aimed at improving survival outcomes based on individual risk profiles, which is a key aspect of precision prevention and treatment.

# %% [markdown]
# ### 2. Gradient Boosting

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train, y_train)
xg_survival_probs = model.predict_proba(X_test)[:, 1]

# %%
# Preview of Gradient Boosting's predicted `Survival Probability`
xg_survival_probs[:5]
# Out:
# array([0.6470811 , 0.89258355, 0.9746849 , 0.8167038 , 0.7867162 ],
#       dtype=float32)

# %%
# Plot distribution of predicted Survival Probability of Gradient Boosting
plt.figure(figsize=(10, 6))
sns.histplot(xg_survival_probs, bins=20, kde=True)
plt.title('Distribution of Survival Probability of Gradient Boosting')
plt.xlabel('Survival Probability')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# This histogram displays the distribution of predicted survival probabilities from the Gradient Boosting model.
#
# *   The histogram shows the frequency of different predicted survival probability values. Compared to the Logistic Regression model, this distribution appears to be more skewed towards higher survival probabilities, with a peak around 0.9. This might suggest that the Gradient Boosting model is more confident in predicting a higher likelihood of survival for a larger portion of the test set.
# *   A distribution with a higher concentration towards the extremes (closer to 0 or 1) generally indicates a model that is more decisive in its predictions. The shape of this histogram suggests that the Gradient Boosting model is providing more polarized predictions (either high or low survival probability) compared to the more centrally peaked distribution from the Logistic Regression model.
# *   Analyzing the distribution of these probabilities from different models is a step towards selecting the most appropriate model for informing personalized interventions based on individual risk profiles, which is a key aspect of precision prevention and treatment. The difference in distributions between the two models highlights the importance of evaluating model performance and calibration when using predicted probabilities for clinical decision-making.

# %% [markdown]
# ### 3. Neural Networks (Deep Learning)

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# Convert X_train and X_test DataFrames to NumPy arrays
X_train_np = X_train.values.astype(np.float32)
X_test_np = X_test.values.astype(np.float32)


model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train_np.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train_np, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=0)

# Predict probability
nn_survival_probs = model.predict(X_test_np)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Plot distribution of Survival Probability from the Neural Network model
plt.figure(figsize=(10, 6))
sns.histplot(nn_survival_probs, bins=20, kde=True)
plt.title('Distribution of Survival Probability of Neural Network')
plt.xlabel('Survival Probability')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# This histogram displays the distribution of predicted survival probabilities from the Neural Network model.
#
# *   The histogram shows the frequency of different predicted survival probability values. This distribution appears to be somewhat similar in shape to the Logistic Regression model's distribution, being more centrally peaked compared to the Gradient Boosting model, although it might be slightly skewed towards higher probabilities.
# *   The shape of this histogram provides insight into how the Neural Network model is distributing its predictions of survival likelihood across the test set. A more spread-out distribution might suggest the model is capturing a wider range of risk profiles, while a more concentrated distribution might indicate the model is less sensitive to subtle differences in the features.
# *   Analyzing the distribution of these probabilities is a crucial step in evaluating the model's performance and understanding how it can be used to inform personalized interventions aimed at improving survival outcomes based on individual risk profiles, which is a key aspect of precision prevention and treatment.

# %%
plt.figure(figsize=(18, 5))
plt.suptitle('Survival Probability Estimates of Logistic Regression, Gradient Boosting, and Neural Network')
plt.subplot(1, 3, 1)

# Plot the distribution
#plt.figure(figsize=(10, 6))
sns.histplot(lr_survival_probs, bins=20, kde=True)
plt.title('Distribution of Survival Probability of Logistic Regression')
plt.xlabel('Survival Probability')
plt.ylabel('Frequency')
#plt.show()

plt.subplot(1, 3, 2)
# Plot distribution of predicted Survival Probability of Gradient Boosting
#plt.figure(figsize=(10, 6))
sns.histplot(xg_survival_probs, bins=20, kde=True)
plt.title('Distribution of Survival Probability of Gradient Boosting')
plt.xlabel('Survival Probability')
plt.ylabel('Frequency')
#plt.show()

# Plot distribution of Survival Probability from the Neural Network model
#plt.figure(figsize=(10, 6))
plt.subplot(1, 3, 3)
sns.histplot(nn_survival_probs, bins=20, kde=True)
plt.title('Distribution of Survival Probability of Neural Network')
plt.xlabel('Survival Probability')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Survival Prediction

# %% [markdown]
# ### 1. Decision Tree

# %%
# Decision Tree for predicting survival
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, y_train)
dt_pred = dt_model.predict(X_test)

# %%
# Check performance
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
print(f'Accuracy: {accuracy_score(y_test, dt_pred)}')
print(f'F1 Score: {f1_score(y_test, dt_pred)}')
print(f'Precision: {precision_score(y_test, dt_pred)}')
print(f'Recall: {recall_score(y_test, dt_pred)}')
# Out:
# Accuracy: 0.558
# F1 Score: 0.6738809640924742
# Precision: 0.6926188068756319
# Recall: 0.6561302681992337

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix

# Get label names
label_names = le.classes_

# Create confusion matrix
cm = confusion_matrix(y_test, dt_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Get top 10 feature importances and plot
feature_importances = pd.Series(dt_model.feature_importances_, index=X_train.columns)
feature_importances.nlargest(10).plot(kind='barh')
plt.title('Top 10 Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# The Decision Tree model was used to predict one-year survival.
#
# **Performance Metrics:**
#
# *   **Accuracy:** Approximately 56.5%
# *   **F1 Score:** Approximately 0.680
# *   **Precision:** Approximately 0.696
# *   **Recall:** Approximately 0.666
#
# These metrics provide an overall assessment of the model's ability to correctly classify survival outcomes. The F1 score, which balances precision and recall, is around 0.68, suggesting a moderate performance in predicting survival.
#
# **Confusion Matrix:**
#
# The confusion matrix shows:
# *   **True Positives (Correctly predicted 'Yes' survival):** 695
# *   **True Negatives (Correctly predicted 'No' survival):** 152
# *   **False Positives (Incorrectly predicted 'Yes' survival):** 304
# *   **False Negatives (Incorrectly predicted 'No' survival):** 349
#
# The model has a higher number of False Negatives (349) compared to True Negatives (152), indicating that it is more likely to incorrectly predict that a patient will survive when they do not.
#
# **Feature Importance:**
#
# The top 10 most important features according to the Decision Tree model are:
#
# 1.  `Tumor_Size_mm`
# 2.  `Age`
# 3.  `Hospital_Type_Private`
# 4.  `Treatment_Chemotherapy`
# 5.  `Air_Pollution_Exposure_High`
# 6.  `Air_Pollution_Exposure_Low`
# 7.  `Diet_Habit_Non-Vegetarian`
# 8.  `Hospital_Type_Medical College`
# 9.  `Diet_Habit_Mixed`
# 10. `Symptoms_Cough`
#
# These features were the most influential in the Decision Tree's decisions for predicting survival. `Tumor_Size_mm` and `Age` appear to be the most important factors in this model. This aligns with clinical understanding that tumor characteristics and age are significant prognostic indicators.

# %% [markdown]
# ### 2. Random Forest

# %%
# Random forest for predicting survival
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

# %%
# Performance
print(f'Accuracy: {accuracy_score(y_test, rf_pred)}')
print(f'F1 Score: {f1_score(y_test, rf_pred)}')
print(f'Precision: {precision_score(y_test, rf_pred)}')
print(f'Recall: {recall_score(y_test, rf_pred)}')
# Out:
# Accuracy: 0.6893333333333334
# F1 Score: 0.8146380270485283
# Precision: 0.6965986394557823
# Recall: 0.9808429118773946

# %%
# Plot confusion matrix
cm = confusion_matrix(y_test, rf_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Plot to 10 feature importances
feature_importances = pd.Series(rf_model.feature_importances_, index=X_train.columns)
feature_importances.nlargest(10).plot(kind='barh')
plt.title('Top 10 Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# The Random Forest model was used to predict one-year survival.
#
# **Performance Metrics:**
#
# *   **Accuracy:** Approximately 68.4%
# *   **F1 Score:** Approximately 0.811
# *   **Precision:** Approximately 0.695
# *   **Recall:** Approximately 0.974
#
# Compared to the Decision Tree, the Random Forest model shows improved performance across all metrics, particularly in Accuracy, F1 Score, and Recall. The high Recall score (0.974) indicates that the model is very good at identifying most of the patients who actually survived ('Yes'). However, the lower Precision (0.695) suggests that when it predicts 'Yes' survival, it is correct about 69.5% of the time.
#
# **Confusion Matrix:**
#
# The confusion matrix shows:
# *   **True Positives (Correctly predicted 'Yes' survival):** 1017
# *   **True Negatives (Correctly predicted 'No' survival):** 9
# *   **False Positives (Incorrectly predicted 'Yes' survival):** 447
# *   **False Negatives (Incorrectly predicted 'No' survival):** 27
#
# The Random Forest model has significantly fewer False Negatives (27) compared to the Decision Tree (349), which aligns with its high Recall. However, it has a much higher number of False Positives (447) compared to the Decision Tree (304) and very few True Negatives (9). This indicates that while the model is effective at identifying survivors, it frequently misclassifies non-survivors as survivors.
#
# **Feature Importance:**
#
# The top 10 most important features according to the Random Forest model are:
#
# 1.  `Tumor_Size_mm`
# 2.  `Age`
# 3.  `Histology_Type_Adenocarcinoma`
# 4.  `Diet_Habit_Mixed`
# 5.  `Diet_Habit_Non-Vegetarian`
# 6.  `Treatment_Chemotherapy`
# 7.  `Air_Pollution_Exposure_Moderate`
# 8.  `Air_Pollution_Exposure_High`
# 9.  `Smoking_Status_Current Smoker`
# 10. `Stage_Stage II`
#
# Similar to the Decision Tree, `Tumor_Size_mm` and `Age` are the most important features. However, the ranking of other features differs, with `Histology_Type_Adenocarcinoma` appearing as the third most important feature in the Random Forest model, which was lower in the Decision Tree's list. This difference in feature importance ranking between models highlights that different algorithms may weigh the influence of various features differently.

# %% [markdown]
# ### 3. Gradient Boosting Classifier

# %%
# XGBoost for predicting survival
from xgboost import XGBClassifier
xgb_model = XGBClassifier()
xgb_model.fit(X_train, y_train)
xgb_pred = xgb_model.predict(X_test)

# %%
# Performance
print(f'Accuracy: {accuracy_score(y_test, xgb_pred)}')
print(f'F1 Score: {f1_score(y_test, xgb_pred)}')
print(f'Precision: {precision_score(y_test, xgb_pred)}')
print(f'Recall: {recall_score(y_test, xgb_pred)}')
# Out:
# Accuracy: 0.6406666666666667
# F1 Score: 0.7675722294092281
# Precision: 0.6980392156862745
# Recall: 0.8524904214559387

# %%
# Plot confusion matrix
cm = confusion_matrix(y_test, xgb_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Plot top 10 feature importances
feature_importances = pd.Series(xgb_model.feature_importances_, index=X_train.columns)
feature_importances.nlargest(10).plot(kind='barh')
plt.title('Top 10 Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# The Gradient Boosting Classifier model was used to predict one-year survival.
#
# **Performance Metrics:**
#
# *   **Accuracy:** Approximately 64.1%
# *   **F1 Score:** Approximately 0.768
# *   **Precision:** Approximately 0.698
# *   **Recall:** Approximately 0.852
#
# The Gradient Boosting model's performance metrics fall between those of the Decision Tree and Random Forest models. It has better Accuracy and F1 Score than the Decision Tree but lower than the Random Forest. Its Recall is also lower than the Random Forest but significantly higher than the Decision Tree. The Precision is similar to the other two models.
#
# **Confusion Matrix:**
#
# The confusion matrix shows:
# *   **True Positives (Correctly predicted 'Yes' survival):** 890
# *   **True Negatives (Correctly predicted 'No' survival):** 71
# *   **False Positives (Incorrectly predicted 'Yes' survival):** 385
# *   **False Negatives (Incorrectly predicted 'No' survival):** 154
#
# The Gradient Boosting model has a more balanced performance in terms of False Positives and False Negatives compared to the Random Forest. It has significantly fewer False Positives (385) than the Random Forest (447) and more True Negatives (71) than the Random Forest (9). While its False Negatives (154) are higher than the Random Forest (27), they are much lower than the Decision Tree (349). This suggests a better trade-off between correctly identifying survivors and incorrectly classifying non-survivors compared to the Random Forest.
#
# **Feature Importance:**
#
# The top 10 most important features according to the Gradient Boosting model are:
#
# 1.  `Diet_Habit_Vegetarian`
# 2.  `Smoking_Status_Never Smoked`
# 3.  `Histology_Type_Small Cell Carcinoma`
# 4.  `Factory_Exposure_No`
# 5.  `Symptoms_Hemoptysis`
# 6.  `Symptoms_Shortness of Breath`
# 7.  `Treatment_Surgery`
# 8.  `Stage_Stage I`
# 9.  `Treatment_Palliative Care`
# 10. `Treatment_Targeted Therapy`
#
# The feature importance ranking for the Gradient Boosting model is quite different from both the Decision Tree and Random Forest models. Lifestyle factors like `Diet_Habit_Vegetarian` and `Smoking_Status_Never Smoked` appear as the top most important features in this model, whereas `Tumor_Size_mm` and `Age`, which were dominant in the other two models, do not appear in the top 10 for Gradient Boosting. Histology type, factory exposure, symptoms, stage, and treatment types are also represented in the top features. This difference in feature importance highlights that Gradient Boosting identifies different relationships and contributions of features to the prediction compared to tree-based methods like Decision Tree and Random Forest.

# %% [markdown]
# ### 4. Neural Network

# %%
# Neural Network for predicting survival
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# Convert X_train and X_test DataFrames to NumPy arrays
X_train_np = X_train.values.astype(np.float32)
y_train_np = y_train.astype(np.float32)
X_test_np = X_test.values.astype(np.float32)
y_test_np = y_test.astype(np.float32)

# Set up network
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train_np.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train_np, y_train_np, epochs=50, batch_size=32, validation_split=0.2, verbose=0)

# Make prediction
nn_pred = model.predict(X_test_np)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# Check performance
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# Convert predicted probabilities to binary predictions
nn_pred_binary = (nn_pred > 0.5).astype(int)

print(f'Accuracy: {accuracy_score(y_test, nn_pred_binary)}')
print(f'F1 Score: {f1_score(y_test, nn_pred_binary)}')
print(f'Precision: {precision_score(y_test, nn_pred_binary)}')
print(f'Recall: {recall_score(y_test, nn_pred_binary)}')
# Out:
# Accuracy: 0.692
# F1 Score: 0.8175355450236966
# Precision: 0.6955645161290323
# Recall: 0.9913793103448276

# %%
# Plot confusion matrix
cm = confusion_matrix(y_test, nn_pred_binary)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Combined
plt.figure(figsize=(20, 5))
plt.suptitle('Confusion Matrix Comparison of Decision Tree, Random Forest, Gradient Boosting Classifier and Neural Network')
plt.subplot(1, 4, 1)

cm = confusion_matrix(y_test, dt_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix of Decisio Tree')
plt.xlabel('Predicted')
plt.ylabel('Actual')
#plt.show()

plt.subplot(1, 4, 2)
cm = confusion_matrix(y_test, rf_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix of Random Forest')
plt.xlabel('Predicted')
plt.ylabel('Actual')
#plt.show()


plt.subplot(1, 4, 3)
cm = confusion_matrix(y_test, xgb_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix Gradient Boosting Classifier')
plt.xlabel('Predicted')
plt.ylabel('Actual')
#plt.show()

plt.subplot(1, 4, 4)
cm = confusion_matrix(y_test, nn_pred_binary)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_names, yticklabels=label_names)
plt.title('Confusion Matrix Neural Network')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.tight_layout()
plt.show()

# %%
# Combined feature importance plots
plt.figure(figsize=(18, 5))
plt.suptitle('Top 10 Feature Importance Comparison of Decision Tree, Random Forest and Gradient Boosting Classifier')
plt.subplot(1, 3, 1)

# Get top 10 feature importances and plot
feature_importances = pd.Series(dt_model.feature_importances_, index=X_train.columns)
feature_importances.nlargest(10).plot(kind='barh')
plt.title('Decision Tree')
plt.xlabel('Importance')
plt.ylabel('Feature')

#plt.show()

plt.subplot(1, 3, 2)
feature_importances = pd.Series(rf_model.feature_importances_, index=X_train.columns)
feature_importances.nlargest(10).plot(kind='barh')
plt.title('Random Forest')
plt.xlabel('Importance')
plt.ylabel('Feature')
#plt.show()


plt.subplot(1, 3, 3)
feature_importances = pd.Series(xgb_model.feature_importances_, index=X_train.columns)
feature_importances.nlargest(10).plot(kind='barh')
plt.title('Gradient Boosting Classifier')
plt.xlabel('Importance')
plt.ylabel('Feature')
#plt.show()

plt.tight_layout()
plt.show()

# %% [markdown]
# The Neural Network model was used to predict one-year survival.
#
# **Performance Metrics:**
#
# *   **Accuracy:** Approximately 68.1%
# *   **F1 Score:** Approximately 0.808
# *   **Precision:** Approximately 0.695
# *   **Recall:** Approximately 0.965
#
# The Neural Network model shows performance metrics comparable to the Random Forest model, with high Accuracy, F1 Score, and Recall. The high Recall score (0.965) indicates that the model is very effective at identifying most of the patients who actually survived ('Yes'). The Precision (0.695) is similar to the Random Forest, suggesting that when it predicts 'Yes' survival, it is correct about 69.5% of the time.
#
# **Confusion Matrix:**
#
# The confusion matrix shows:
# *   **True Positives (Correctly predicted 'Yes' survival):** 1007
# *   **True Negatives (Correctly predicted 'No' survival):** 15
# *   **False Positives (Incorrectly predicted 'Yes' survival):** 441
# *   **False Negatives (Incorrectly predicted 'No' survival):** 37
#
# Similar to the Random Forest, the Neural Network model has a low number of False Negatives (37), aligning with its high Recall. However, it also has a high number of False Positives (441) and a low number of True Negatives (15). This indicates that while the model is good at identifying survivors, it frequently misclassifies non-survivors as survivors.
#
# *(Note: Neural Network models do not provide feature importances in the same straightforward way as tree-based models like Decision Trees and Random Forests.)*

# %% [markdown]
# ### 5. Analysis of Models' Predictions
#
# Evaluated four different models for predicting survival: `Decision Tree`, `Random Forest`, `Gradient Boosting` and `Neural Network`. Here's a comparative analysis of their performance based on the calculated metrics and confusion matrices:
#
# **Performance Metrics Summary:**
#
# | Model             | Accuracy | F1 Score | Precision | Recall  |
# |-------------------|----------|----------|-----------|---------|
# | Decision Tree     | 0.565    | 0.680    | 0.696     | 0.666   |
# | Random Forest     | 0.684    | 0.811    | 0.695     | 0.974   |
# | Gradient Boosting | 0.641    | 0.768    | 0.698     | 0.852   |
# | Neural Network    | 0.681    | 0.808    | 0.695     | 0.965   |
#
# **Comparative Analysis:**
#
# *   **Accuracy:** The `Random Forest` and `Neural Network` models achieved the highest accuracy (`around 68%`), indicating they correctly classified the largest proportion of patients. The `Decision Tree` had the lowest accuracy.
# *   **F1 Score:** Similar to accuracy, `Random Forest` and `Neural Network` have the highest F1 scores (`around 0.81`), suggesting a better balance between precision and recall. The `Decision Tree` has the lowest F1 score.
# *   **Precision:** All four models have relatively similar precision scores (`around 0.69-0.70`). Precision is the ability of the model not to label as positive a sample that is negative. This means when the models predict a patient will survive (`'Yes'`), they are correct about `69-70%` of the time.
# *   **Recall:** The `Random Forest` model has a significantly higher recall (`0.974`) than the other models, followed closely by the `Neural Network` (`0.965`). Recall is the ability of the model to find all the positive samples. A high recall indicates that these models are very good at identifying patients who actually survived. The `Decision Tree` has the lowest recall.
#
# **Confusion Matrix Analysis:**
#
# Looking at the confusion matrices provides a more detailed picture:
#
# *   **Decision Tree:** Shows a significant number of `False Negatives` (349), meaning it missed a substantial number of actual survivors. It also has a moderate number of `False Positives` (304).
# *   **Random Forest:** Exhibits a very high number of `True Positives` (1017) and very low `False Negatives` (27), consistent with its high recall. However, it also has a high number of `False Positives` (447) and very low `True Negatives` (9), indicating it frequently misclassifies non-survivors as survivors.
# *   **Gradient Boosting:** Provides a more balanced performance compared to the `Random Forest`. It has fewer `False Positives` (385) and more `True Negatives` (71) than the `Random Forest`, while having more `False Negatives` (154) but significantly fewer than the `Decision Tree`.
# *   **Neural Network:** Shows a similar pattern to the `Random Forest`, with a high number of `True Positives` (1007) and low `False Negatives` (37). It also has a high number of `False Positives` (441) and low `True Negatives` (15), indicating a tendency to over-predict survival, similar to the `Random Forest`.
#
# **Conclusion on Model Performance for Precision Prevention:**
#
# For the purpose of **Interaction of Factors in Lung Cancer**, a model with high recall is particularly valuable. Identifying individuals who are likely to survive ('Yes') is important for confirming the effectiveness of interventions. However, a high number of false positives (predicting survival when it doesn't occur) can lead to a false sense of security.
#
# The **Random Forest** and **Neural Network** models demonstrate the highest ability to identify actual survivors (high recall). However, their high number of false positives is a concern. The **Gradient Boosting** model offers a better balance between identifying survivors and correctly identifying non-survivors (better trade-off between recall and precision/true negatives). The **Decision Tree** performs the worst overall.
#
# The choice of the "best" model depends on the specific goals of the precision prevention program. If the priority is to identify as many potential survivors as possible for positive reinforcement or to assess the upper bound of intervention effectiveness (and the cost of false positives is less critical), then Random Forest or Neural Network might be preferred due to their high recall. If a more balanced approach is needed, where correctly identifying non-survivors is also important (e.g., for targeting intensive interventions), the Gradient Boosting model might be more suitable.
#
# Regardless of the model, the predicted survival probabilities can be used to stratify risk. Individuals with lower predicted probabilities (even if classified as 'Yes' by models with high false positives) could be flagged for personalized intervention strategies to potentially improve their outcomes, aligning with the principles of precision prevention. Future work could involve fine-tuning these models and incorporating explicit genetic data (if available) to build even more precise predictive models.
